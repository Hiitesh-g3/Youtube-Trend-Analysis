# %%
# 📌 1. Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from wordcloud import WordCloud

# Settings
plt.style.use('seaborn-v0_8')  # updated for matplotlib 3.6+
sns.set_palette('pastel')
# %matplotlib inline

# 📌 2. Load the Dataset
df = pd.read_csv('../data/processed_data.csv')  # adjust path if needed

# 📌 3. Quick Look at the Data
print("🔍 Data Shape:", df.shape)
display(df.head())

# 📌 4. Basic Info and Missing Values
print("\n🔍 Data Info:")
df.info()

print("\n🔍 Missing Values:")
print(df.isnull().sum())

# 📌 5. Parse publish_time to datetime (if not already)
df['publish_time'] = pd.to_datetime(df['publish_time'], errors='coerce')

# 📌 6. Create New Time-Based Features
df['publish_day'] = df['publish_time'].dt.day_name()
df['publish_hour'] = df['publish_time'].dt.hour
df['publish_month'] = df['publish_time'].dt.month_name()

# 📌 7. 🛠️ Map Category ID to Category Name (Quick Fix for Missing 'category')
if 'category_id' in df.columns and 'category' not in df.columns:
    category_mapping = {
        1: "Film & Animation",
        2: "Autos & Vehicles",
        10: "Music",
        15: "Pets & Animals",
        17: "Sports",
        18: "Short Movies",
        19: "Travel & Events",
        20: "Gaming",
        21: "Videoblogging",
        22: "People & Blogs",
        23: "Comedy",
        24: "Entertainment",
        25: "News & Politics",
        26: "Howto & Style",
        27: "Education",
        28: "Science & Technology",
        29: "Nonprofits & Activism",
    }
    df['category'] = df['category_id'].map(category_mapping)

# 📌 8. Top Categories by Number of Trending Videos
if 'category' in df.columns:
    top_categories = df['category'].value_counts().sort_values(ascending=False)

    plt.figure(figsize=(12,6))
    sns.barplot(x=top_categories.values, y=top_categories.index, palette="muted")
    plt.title('Top Trending Video Categories', fontsize=16)
    plt.xlabel('Number of Videos')
    plt.ylabel('Category')
    plt.tight_layout()
    plt.show()

# 📌 9. Most Popular Categories Over Time
if 'category' in df.columns:
    popular_cat_time = df.groupby(['publish_month', 'category']).size().reset_index(name='counts')
    fig = px.sunburst(popular_cat_time, path=['publish_month', 'category'], values='counts',
                      title='Popular Categories Over Months')
    fig.write_html("sunburst_chart.html")


# 📌 10. Best Days for Uploads (Highest Views Average)
views_by_day = df.groupby('publish_day')['views'].mean().reindex([
    'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'
])

plt.figure(figsize=(10,5))
sns.barplot(x=views_by_day.index, y=views_by_day.values)
plt.title('Average Views by Day of the Week', fontsize=16)
plt.xlabel('Day of the Week')
plt.ylabel('Average Views')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 📌 11. Best Hours for Uploads
views_by_hour = df.groupby('publish_hour')['views'].mean()

plt.figure(figsize=(12,6))
sns.lineplot(x=views_by_hour.index, y=views_by_hour.values, marker='o')
plt.title('Average Views by Hour of Upload', fontsize=16)
plt.xlabel('Hour of the Day')
plt.ylabel('Average Views')
plt.grid(True)
plt.tight_layout()
plt.show()

# 📌 12. Correlation Heatmap (Views, Likes, etc.)
numerical_cols = ['views', 'likes']
numerical_cols = [col for col in numerical_cols if col in df.columns]

if len(numerical_cols) >= 2:
    plt.figure(figsize=(8,5))
    sns.heatmap(df[numerical_cols].corr(), annot=True, cmap='coolwarm')
    plt.title('Correlation Heatmap')
    plt.tight_layout()
    plt.show()

# 📌 13. Top 10 Most Viewed Videos
top_videos = df[['title', 'views']].sort_values(by='views', ascending=False).head(10)

fig = px.bar(top_videos, x='views', y='title', orientation='h',
             title='Top 10 Most Viewed Trending Videos')
fig.update_layout(yaxis={'categoryorder':'total ascending'})
fig.write_html("sunburst_chart.html")


# 📌 14. Word Cloud of Video Tags
if 'tags' in df.columns:
    all_tags = ' '.join(df['tags'].dropna().astype(str))

    wordcloud = WordCloud(width=1200, height=600, background_color='white').generate(all_tags)

    plt.figure(figsize=(15,7))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title('Word Cloud of Video Tags', fontsize=20)
    plt.show()

# 📌 15. Final Key Insights
print("\n🔎 Final Key Insights:")
if 'category' in df.columns:
    print("- Top 3 most popular categories are:", list(top_categories.index[:3]))
if not views_by_day.empty:
    print("- Best day to upload videos for high views:", views_by_day.idxmax())
if not views_by_hour.empty:
    print("- Best hour to upload for maximum views: Around", views_by_hour.idxmax(), "hours.")
if len(numerical_cols) >= 2:
    print("- Views and likes have a strong positive correlation.")



# plt.savefig('../plots/top_categories.png')
# Out:
# 🔍 Data Shape: (181787, 20)
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id               publish_time  \
# 0           10  2017-11-10 17:00:03+00:00
# 1           23  2017-11-13 17:00:00+00:00
# 2           23  2017-11-12 19:05:24+00:00
# 3           24  2017-11-12 18:01:41+00:00
# 4           10  2017-11-09 11:04:14+00:00
#
#                                                 tags     views     likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  0.040416  0.140265
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...  0.002389  0.022764
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  0.007517  0.026013
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  0.004936  0.023556
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  0.078964  0.291090
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0  0.022324       0.077394  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1  0.000868       0.008011  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2  0.002745       0.005030  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3  0.001023       0.010770  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4  0.010839       0.052301  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description  publish_day  \
# 0  Eminem's new track Walk on Water ft. Beyoncé i...           10
# 1  STill got a lot of packages. Probably will las...           13
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...           12
# 3  I know it's been a while since we did this sho...           12
# 4  🎧: https://ad.gt/yt-perfect\n💰: https://atlant...            9
#
#    publish_month  publish_hour  category_id_encoded
# 0             11            17                    2
# 1             11            17                    8
# 2             11            19                    8
# 3             11            18                    9
# 4             11            11                    2
# 🔍 Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181787 entries, 0 to 181786
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   video_id                181787 non-null  object
#  1   trending_date           181787 non-null  object
#  2   title                   181787 non-null  object
#  3   channel_title           181787 non-null  object
#  4   category_id             181787 non-null  int64
#  5   publish_time            181787 non-null  object
#  6   tags                    181787 non-null  object
#  7   views                   181787 non-null  float64
#  8   likes                   181787 non-null  float64
#  9   dislikes                181787 non-null  float64
#  10  comment_count           181787 non-null  float64
#  11  thumbnail_link          181787 non-null  object
#  12  comments_disabled       181787 non-null  bool
#  13  ratings_disabled        181787 non-null  bool
#  14  video_error_or_removed  181787 non-null  bool
#  15  description             181787 non-null  object
#  16  publish_day             181787 non-null  int64
#  17  publish_month           181787 non-null  int64
#  18  publish_hour            181787 non-null  int64
#  19  category_id_encoded     181787 non-null  int64
# dtypes: bool(3), float64(4), int64(5), object(8)
# memory usage: 24.1+ MB
#
# 🔍 Missing Values:
# video_id                  0
# trending_date             0
# title                     0
# channel_title             0
# category_id               0
# publish_time              0
# tags                      0
# views                     0
# likes                     0
# dislikes                  0
# comment_count             0
# thumbnail_link            0
# comments_disabled         0
# ratings_disabled          0
# video_error_or_removed    0
# description               0
# publish_day               0
# publish_month             0
# publish_hour              0
# category_id_encoded       0
# dtype: int64
# C:\Users\hiite\AppData\Local\Temp\ipykernel_18024\383189982.py:64: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# 🔎 Final Key Insights:
# - Top 3 most popular categories are: ['Entertainment', 'Music', 'People & Blogs']
# - Best day to upload videos for high views: Friday
# - Best hour to upload for maximum views: Around 5 hours.
# - Views and likes have a strong positive correlation.
